# %%
import pandas as pd

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split

from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
category_features = ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal']
numeric_features =['age', 'trestbps', 'chol', 'thalach', 'oldpeak']

# %%
# !pip freeze
# Out:
# absl-py==0.12.0
# aiohttp==3.6.2
# alabaster==0.7.12
# anaconda-client==1.7.2
# anaconda-navigator==1.9.12
# anaconda-project==0.8.3
# appdirs==1.4.4
# argh==0.26.2
# asn1crypto==1.3.0
# astroid==2.3.3
# astropy==4.0
# async-timeout==3.0.1
# atomicwrites==1.3.0
# attrs==19.3.0
# autopep8==1.4.4
# b-labs-models==2017.8.22
# Babel==2.8.0
# backcall==0.1.0
# backports.functools-lru-cache==1.6.1
# backports.shutil-get-terminal-size==1.0.0
# backports.tempfile==1.0
# backports.weakref==1.0.post1
# bcrypt==3.1.7
# beautifulsoup4==4.8.2
# bitarray==1.2.1
# bkcharts==0.2
# bleach==3.1.0
# bokeh==1.4.0
# boto==2.49.0
# Bottleneck==1.3.2
# branca==0.4.1
# bs4==0.0.1
# certifi==2019.11.28
# cffi==1.14.0
# chardet==3.0.4
# click==7.1.2
# cloudpickle==1.3.0
# clyent==1.2.2
# colorama==0.4.3
# comtypes==1.1.7
# conda==4.9.2
# conda-build==3.18.11
# conda-package-handling==1.6.0
# conda-verify==3.4.2
# contextlib2==0.6.0.post1
# cryptography==2.8
# cssselect==1.1.0
# cycler==0.10.0
# Cython==0.29.14
# cytoolz==0.10.1
# dadata==20.7.0
# dask==2.11.0
# dateparser==1.0.0
# DAWG-Python==0.7.2
# decorator==4.4.1
# defusedxml==0.6.0
# diff-match-patch==20181111
# distributed==2.11.0
# docopt==0.6.2
# docutils==0.16
# entrypoints==0.3
# et-xmlfile==1.0.1
# fake-useragent==0.1.11
# fastcache==1.1.0
# feedfinder2==0.0.4
# feedparser==6.0.2
# filelock==3.0.12
# flake8==3.7.9
# Flask==1.1.1
# folium==0.11.0
# fsspec==0.6.2
# future==0.18.2
# futures==3.1.1
# gensim==3.8.3
# geoip2==4.0.2
# geojson==2.5.0
# gevent==1.4.0
# glob2==0.7
# GoogleNews==1.5.1
# greenlet==0.4.15
# grpcio==1.35.0
# grpcio-tools==1.35.0
# h11==0.9.0
# h5py==2.10.0
# hdbscan==0.8.26
# HeapDict==1.0.1
# html5lib==1.0.1
# httpcore==0.10.2
# httpx==0.14.1
# hypothesis==5.5.4
# idna==2.8
# imageio==2.6.1
# imagesize==1.2.0
# importlib-metadata==2.1.1
# intervaltree==3.0.2
# ipykernel==5.1.4
# ipython==7.12.0
# ipython-genutils==0.2.0
# ipywidgets==7.5.1
# isort==4.3.21
# itsdangerous==1.1.0
# jdcal==1.4.1
# jedi==0.14.1
# jieba3k==0.35.1
# Jinja2==2.11.1
# joblib==0.14.1
# json5==0.9.1
# jsonschema==3.2.0
# jupyter==1.0.0
# jupyter-client==5.3.4
# jupyter-console==6.1.0
# jupyter-contrib-core==0.3.3
# jupyter-contrib-nbextensions==0.5.1
# jupyter-core==4.6.1
# jupyter-highlight-selected-word==0.2.0
# jupyter-latex-envs==1.4.6
# jupyter-nbextensions-configurator==0.4.1
# jupyterlab==1.2.6
# jupyterlab-server==1.0.6
# k-means-constrained==0.5.2
# keyring==21.1.0
# kiwisolver==1.1.0
# Lasagne==0.2.dev1
# lazy-object-proxy==1.4.3
# libarchive-c==2.8
# lightgbm==3.1.1
# llvmlite==0.31.0
# locket==0.2.0
# lxml==4.5.0
# MarkupSafe==1.1.1
# matplotlib==3.1.3
# matplotlib-venn==0.11.5
# maxminddb==2.0.2
# mccabe==0.6.1
# menuinst==1.4.16
# mistune==0.8.4
# mkl-fft==1.0.15
# mkl-random==1.1.0
# mkl-service==2.3.0
# mock==4.0.1
# more-itertools==8.2.0
# Morfessor==2.0.6
# mpmath==1.1.0
# msgpack==0.6.1
# multidict==4.7.6
# multipledispatch==0.6.0
# navigator-updater==0.2.1
# nbconvert==5.6.1
# nbformat==5.0.4
# networkx==2.4
# newspaper3k==0.2.8
# nltk==3.4.5
# nose==1.3.7
# notebook==6.0.3
# numba==0.48.0
# numexpr==2.7.1
# numpy==1.20.2
# numpydoc==0.9.2
# olefile==0.46
# openpyxl==3.0.3
# ortools==8.2.8710
# osmapi==1.3.0
# packaging==20.1
# pandas==1.2.3
# pandas-profiling==1.4.1
# pandocfilters==1.4.2
# paramiko==2.7.1
# parse==1.19.0
# parso==0.5.2
# partd==1.1.0
# path==13.1.0
# pathlib2==2.3.5
# pathtools==0.1.2
# patsy==0.5.1
# pep8==1.7.1
# pexpect==4.8.0
# pickleshare==0.7.5
# Pillow==7.0.0
# pkginfo==1.5.0.1
# plotly==4.6.0
# pluggy==0.13.1
# ply==3.11
# prometheus-client==0.7.1
# prompt-toolkit==3.0.3
# protobuf==3.14.0
# psutil==5.6.7
# py==1.8.1
# pybind11==2.5.0
# pycld2==0.41
# pycodestyle==2.5.0
# pycosat==0.6.3
# pycparser==2.19
# pycrypto==2.6.1
# pycurl==7.43.0.5
# pydocstyle==4.0.1
# pyee==8.1.0
# pyflakes==2.1.1
# Pygments==2.5.2
# PyICU==2.6
# pylint==2.4.4
# pymorphy2==0.8
# pymorphy2-dicts==2.4.393442.3710985
# pymorphy2-dicts-ru==2.4.417127.4579844
# pymystem3==0.2.0
# PyNaCl==1.3.0
# pyodbc===4.0.0-unsupported
# pyOpenSSL==19.1.0
# pyparsing==2.4.6
# pyppeteer==0.2.5
# pyquery==1.4.3
# pyreadline==2.1
# pyrsistent==0.15.7
# PySocks==1.7.1
# pytest==5.3.5
# pytest-arraydiff==0.3
# pytest-astropy==0.8.0
# pytest-astropy-header==0.1.2
# pytest-doctestplus==0.5.0
# pytest-openfiles==0.4.0
# pytest-remotedata==0.3.2
# python-crfsuite==0.9.7
# python-dateutil==2.8.1
# python-jsonrpc-server==0.3.4
# python-language-server==0.31.7
# pytz==2019.3
# PyWavelets==1.1.1
# pywin32==227
# pywin32-ctypes==0.2.0
# pywinpty==0.5.7
# PyYAML==5.3
# pyzmq==18.1.1
# QDarkStyle==2.8
# QtAwesome==0.6.1
# qtconsole==4.6.0
# QtPy==1.9.0
# razdel==0.4.0
# regex==2020.11.13
# requests==2.24.0
# requests-file==1.5.1
# requests-html==0.10.0
# retrying==1.3.3
# rfc3986==1.4.0
# rope==0.16.0
# Rtree==0.9.3
# ruamel-yaml==0.15.87
# russian-tagsets==0.6
# scikit-image==0.16.2
# scikit-learn==0.22.1
# scikit-surprise==1.1.1
# scipy==1.4.1
# seaborn==0.10.0
# selenium==3.141.0
# Send2Trash==1.5.0
# sgmllib3k==1.0.0
# simplegeneric==0.8.1
# singledispatch==3.4.0.3
# six==1.14.0
# smart-open==3.0.0
# sniffio==1.1.0
# snowballstemmer==2.0.0
# sortedcollections==1.1.2
# sortedcontainers==2.1.0
# soupsieve==1.9.5
# Sphinx==2.4.0
# sphinxcontrib-applehelp==1.0.1
# sphinxcontrib-devhelp==1.0.1
# sphinxcontrib-htmlhelp==1.0.2
# sphinxcontrib-jsmath==1.0.1
# sphinxcontrib-qthelp==1.0.2
# sphinxcontrib-serializinghtml==1.1.3
# sphinxcontrib-websupport==1.2.0
# spyder==4.0.1
# spyder-kernels==1.8.1
# SQLAlchemy==1.3.13
# statsmodels==0.11.0
# sympy==1.5.1
# tables==3.6.1
# tblib==1.6.0
# terminado==0.8.3
# testpath==0.4.4
# Theano==1.0.5+unknown
# tinysegmenter==0.3
# tldextract==3.1.0
# toolz==0.10.0
# tornado==6.0.3
# tqdm==4.42.1
# traitlets==4.3.3
# typing-extensions==3.7.4.2
# tzlocal==2.1
# ujson==1.35
# unicodecsv==0.14.1
# urllib3==1.25.8
# utm==0.7.0
# w3lib==1.22.0
# watchdog==0.10.2
# wcwidth==0.1.8
# webencodings==0.5.1
# websockets==8.1
# Werkzeug==1.0.0
# widgetsnbextension==3.5.1
# win-inet-pton==1.1.0
# win-unicode-console==0.5
# wincertstore==0.2
# wordcloud==1.8.0
# wrapt==1.11.2
# xlrd==1.2.0
# XlsxWriter==1.2.7
# xlwings==0.17.1
# xlwt==1.3.0
# xmltodict==0.12.0
# yapf==0.28.0
# yarl==1.5.1
# zict==1.0.0
# zipp==2.2.0
# WARNING: Could not generate requirement for distribution -umpy 1.18.1 (c:\users\vkruglikova\anaconda3\lib\site-packages): Parse error at "'-umpy==1'": Expected W:(abcd...)
# WARNING: Could not generate requirement for distribution -rpcio 1.27.2 (c:\users\vkruglikova\anaconda3\lib\site-packages): Parse error at "'-rpcio=='": Expected W:(abcd...)

# %%
make_dataset.split_train_test_data(df, a.SplittingParams())
# Out:
# (     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
#  281   52    1   0       128   204    1        1      156      1      1.0
#  78    52    1   1       128   205    1        1      184      0      0.0
#  292   58    0   0       170   225    1        0      146      1      2.8
#  232   55    1   0       160   289    0        0      145      1      0.8
#  219   48    1   0       130   256    1        0      150      1      0.0
#  ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
#  251   43    1   0       132   247    1        0      143      1      0.1
#
#       slope  ca  thal  target
#  179      1   1     1       0
#  228      1   0     3       0
#  111      2   1     3       1
#  246      1   2     3       0
#  60       2   1     2       1
#  9        2   0     2       1
#  119      1   0     2       1
#  223      0   2     3       0
#  268      1   2     2       0
#  33       0   1     2       1
#  5        1   0     1       1
#  101      0   0     3       1
#  45       2   0     2       1
#  175      1   0     3       0
#  118      2   0     2       1
#  46       2   0     2       1
#  125      2   0     2       1
#  192      1   1     3       0
#  285      1   2     3       0
#  279      1   1     2       0
#  152      1   0     3       1
#  269      0   0     3       0
#  272      1   0     2       0
#  25       2   2     2       1
#  146      1   1     2       1
#  283      2   0     3       0
#  254      2   0     2       0
#  73       2   0     2       1
#  231      1   3     3       0
#  109      2   0     2       1
#  139      1   1     3       1
#  284      2   1     3       0
#  198      1   2     3       0
#  42       1   0     2       1
#  17       0   0     2       1
#  168      1   1     3       0
#  76       1   0     2       1
#  90       2   2     2       1
#  24       2   0     3       1
#  57       2   0     2       1
#  92       2   4     2       1
#  77       2   0     2       1
#  137      2   0     2       1
#  116      1   0     2       1
#  7        2   0     3       1
#  251      1   4     3       0  )

# %%
df = pd.read_csv('../data/raw/heart.csv')

# %%
train_data, test_data = train_test_split(
        df, test_size = 0.2, 
        random_state = 42
    )

# %%
train_data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 132   42    1   1       120   295    0        1      162      0      0.0
# 202   58    1   0       150   270    0        0      111      1      0.8
# 196   46    1   2       150   231    0        1      147      0      3.6
# 75    55    0   1       135   250    0        0      161      0      1.4
# 176   60    1   0       117   230    1        1      160      1      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 188   50    1   2       140   233    0        1      163      0      0.6
# 71    51    1   2        94   227    0        1      154      1      0.0
# 106   69    1   3       160   234    1        0      131      0      0.1
# 270   46    1   0       120   249    0        0      144      0      0.8
# 102   63    0   1       140   195    0        1      179      0      0.0
#
#      slope  ca  thal  target
# 132      2   0     2       1
# 202      2   0     3       0
# 196      1   0     2       0
# 75       1   0     2       1
# 176      2   2     3       0
# ..     ...  ..   ...     ...
# 188      1   1     3       0
# 71       2   1     3       1
# 106      1   1     2       1
# 270      2   0     3       0
# 102      2   2     2       1
#
# [242 rows x 14 columns]

# %%
categorical_pipeline = Pipeline(
    [
        ("ohe", OneHotEncoder(sparse=False)),
    ]
)


numerical_pipeline = Pipeline(
    [
        ("scaler", StandardScaler()),
    ]
)

# %%
pipeline = Pipeline(steps=[
            ('feature_processing', FeatureUnion(
                transformer_list=[
                    ('numeric_processing', numerical_pipeline(numeric_features)),
                    ('category_processing', categorical_pipeline(category_features)),
                ]
            ))
        ])

pipeline.fit(train_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-5ea5f81cb075> in <module>
#       2             ('feature_processing', FeatureUnion(
#       3                 transformer_list=[
# ----> 4                     ('numeric_processing', numerical_pipeline(numeric_features)),
#       5                     ('category_processing', categorical_pipeline(category_features)),
#       6                 ]
#
# TypeError: 'Pipeline' object is not callable
